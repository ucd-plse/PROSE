# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import os
from glob import glob
import pickle
from copy import deepcopy

# %%
ERROR_METRICS = [
    "Energy/Mass",
    "Maximum CFL",
    "Mean Sea Level",
    "Total Mass",
    "Mean Salin",
    "Frac Mass Err",
    "Salin Err",
    "Temp Err",
]

def plot_performance_vs_correctness(df, error_type, norm):
    
    df_plot = df.dropna(subset=["Cost", f"{error_type} ({norm})"])
    baseline_cost = df_plot[(df_plot['Configuration Number'] == 0)]['Cost'].iloc[0]
    df_plot = df_plot.assign(Improvement = baseline_cost/df_plot['Cost'])
    
    fig = px.scatter(
        df_plot,
        x="Improvement",
        y=f"{error_type} ({norm})",
        color = '32-bit %',
        hover_data = ['Configuration Number'],
        log_y = True, 
    )
    fig.update_traces(
        marker={
            'size' : 14,
            'opacity' : 0.5,
            'line_width' : 1,
            'line_color' : "black",
        }
    )
    if not df_plot[df_plot["Configuration Number"] == 1].empty:
        fig.add_trace(
            go.Scatter(
                x = df_plot[df_plot["Configuration Number"] == 1]["Improvement"],
                y = df_plot[df_plot["Configuration Number"] == 1][error_type],
                mode = "markers+text",
                marker_symbol = 'circle-open',
                marker_size = 14,
                marker_color = "black",
                marker_line_width = 3,
                marker_line_color = "black",
                name = "Uniform 32-bit",
                showlegend=False,
                text=["Uniform 32-bit"],
                textposition=["top right"],
                textfont_size=16
            )
        )

    fig.update_layout(
        title=dict(
            text = "MOM6",
            y = 0.98,
            x = 0.5,
            xanchor = 'center',
            yanchor = 'top',
            font_size=30,
        ),
        width = 600,
        height = 300,
        coloraxis_showscale = True,
        yaxis_tickformat = "f",
        xaxis_tickformat = ".1f",
        xaxis_ticksuffix = "x",
        xaxis_title = "",
        yaxis_title = "Relative Error",
        font_size = 20,
        font_family = "Times New Roman",
        legend = dict(
            bgcolor = "#E5ECF6",
            entrywidth = 130,
            orientation = "h",
            yanchor = "bottom",
            xanchor = "right",
            x = 1.0,
            y = 1.02,
            title_text = ""
        ),
        margin = dict(
            r = 0,
            t = 40,
            b = 0,
            l = 0,
        ),
    coloraxis={
        "cmin" : 0,
        "cmax" : 100,
        "colorbar" : {
            'thickness' : 18,
            'title' : "% 32-bit<br>(Hotspot)",
            'orientation' : 'h',
            'title_font_size' : 24,
            'y' : -0.6,
            'len' : 0.8
        },
    },
    )
    fig.add_vline(x=1.0, line_width=2, line_dash="dash", line_color="grey")
    fig.add_hline(y=0.25, line_width=2, line_dash="dash", line_color="grey")

    return fig, df_plot


def plot_label_frequency(df):

    fig = px.histogram(
        df,
        x = "Label",
    )
    fig.update_layout(
        font_size = 18
    )

    return fig


def get_MOM6_data(search_log_path):

    with open(search_log_path, "r") as f:
        search_log_lines = f.readlines()

    df_entire = []
    df_subset = []
    for line in search_log_lines:
        print(line)
        row = {}

        try:
            row['Configuration Number'] = int(line.split(":")[0])
        except ValueError:
            continue
        config_dir_path = os.path.join(os.path.dirname(search_log_path), f"{row['Configuration Number']:0>4}")

        config_path = glob(f"{config_dir_path}/config*")
        assert ( len(config_path) == 1)
        row['Configuration Path'] = config_path[0]

        float_count = 0
        double_count = 0
        with open(row['Configuration Path'], "r" ) as f:
            llines = f.readlines()
            for lline in llines:
                if ",4" in lline:
                    float_count += 1
                elif ",8" in lline:
                    double_count += 1

        row['32-bit %'] = 100*(float_count / (double_count + float_count))

        if "[PASSED]" in line:
            row['Label'] = "Passed"
        elif "error threshold was exceeded" in line:
            row['Label'] = "Exceeded Error Threshold"
        elif "(timeout)" in line:
            row['Label'] = "Timeout"
        elif "(runtime failure)" in line:
            row['Label'] = "Runtime Error"
        elif "(compilation error)" in line:
            row['Label'] = 'Compilation Error'
        elif "(plugin error)" in line:
            row['Label'] = 'Prose Plugin Error'
        else:
            continue

        try:
            with open(os.path.join(config_dir_path, "errors_L2.npy"), "rb") as f:
                errors = np.load(f)
            for i, metric in enumerate(ERROR_METRICS):
                row[f"{metric} (L2 norm)"] = errors[i]

            with open(os.path.join(config_dir_path, "errors_inf.npy"), "rb") as f:
                errors = np.load(f)
            for i, metric in enumerate(ERROR_METRICS):
                row[f"{metric} (inf norm)"] = errors[i]

        except FileNotFoundError:
            for metric in ERROR_METRICS:
                row[f"{metric} (L2 norm)"] = np.nan
                row[f"{metric} (inf norm)"] = np.nan
 
        try:
            row['Cost'] = float(line.split()[4])
        except ValueError:
            try:
                row['Cost'] = float(line.split()[5])
            except ValueError:
                row['Cost'] = np.nan

        df_entire.append(deepcopy(row))

        try:
            with open(os.path.join(config_dir_path, "gptl_subset_info.pckl"), "rb") as f:
                gptl_subset_info = pickle.load(f)

            import subprocess
            subprocess.run(
                f"tar -xvf gptl_timing.tar.gz",
                shell = True,
                cwd = config_dir_path,
                stdout=subprocess.DEVNULL,
                stderr=subprocess.DEVNULL
            )

            execution_counts = {}
            with open(os.path.join(config_dir_path, "timing.000000"), "r") as f:
                for line in f.readlines():
                    if line[2:].lstrip().startswith("::"):
                        procedure_name = line[2:].split()[0].strip().lower()
                        execution_count = float(line[2:].split()[1].strip())
                        execution_counts[procedure_name] = execution_count

            subprocess.run(
                f"rm timing.*",
                shell = True,
                cwd = config_dir_path,
                stdout=subprocess.DEVNULL,
                stderr=subprocess.DEVNULL
            )

            for key, value in gptl_subset_info.items():
                row['Procedure Name'] = key
                row['CPU Time'] = value
                try:
                    row["Execution Count"] = execution_counts[row['Procedure Name'].lower()]
                except KeyError:
                    row["Execution Count"] = np.nan
                float_count = 0
                double_count = 0
                config_hash = ""
                with open(row['Configuration Path'], "r" ) as f:
                    llines = f.readlines()
                    for lline in llines:
                        if lline.strip().lower().startswith(key.lower() + "::"):
                            if ",4" in lline:
                                float_count += 1
                                config_hash = config_hash + "4"
                            elif ",8" in lline:
                                double_count += 1
                                config_hash = config_hash + "8"
                
                row["config_hash"] = hash(config_hash)

                try:
                    row['32-bit %'] = 100*(float_count / (double_count + float_count))
                except Exception as e:
                    row['32-bit %'] = np.nan

                df_subset.append(deepcopy(row))

        except FileNotFoundError:
            continue

    return pd.DataFrame(df_entire), pd.DataFrame(df_subset)

# %%
df_entire, df_subset = get_MOM6_data("./prose_logs/__search_log_12hr.txt")
# Out:
# 0000: [PASSED] subset cost = 6.310 (total cost = 407.219)
#
# 0001: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0002: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0003: [FAILED] subset cost = 37.440 (total cost = 765.834) but error threshold was exceeded
#
# 0004: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0005: [FAILED] subset cost = 31.882 (total cost = 712.011) but error threshold was exceeded
#
# 0006: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0007: [FAILED] subset cost = 17.613 (total cost = 505.293) but error threshold was exceeded
#
# 0008: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0009: [FAILED] subset cost = 37.497 (total cost = 847.684) but error threshold was exceeded
#
# 0010: [FAILED] subset cost = 31.374 (total cost = 724.439) but error threshold was exceeded
#
# 0011: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0012: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0013: [FAILED] subset cost = 5.811 (total cost = 407.031) but error threshold was exceeded
#
# 0014: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0015: [FAILED] subset cost = 30.054 (total cost = 705.900) but error threshold was exceeded
#
# 0016: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0017: [FAILED] subset cost = 7.581 (total cost = 422.922) but error threshold was exceeded
#
# 0018: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0019: [FAILED] subset cost = 17.561 (total cost = 492.998) but error threshold was exceeded
#
# 0020: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0021: [PASSED] subset cost = 15.815 (total cost = 491.561)
#
# 0022: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0023: [FAILED] subset cost = 35.236 (total cost = 771.243) but error threshold was exceeded
#
# 0024: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0025: [FAILED] subset cost = 23.929 (total cost = 585.607) but error threshold was exceeded
#
# 0026: [FAILED] subset cost = 28.505 (total cost = 659.933) but error threshold was exceeded
#
# 0027: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0028: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0029: [PASSED] subset cost = 6.842 (total cost = 404.519)
#
# 0030: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0031: [FAILED] subset cost = 6.650 (total cost = 409.419) but error threshold was exceeded
#
# 0032: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0033: [FAILED] subset cost = 10.338 (total cost = 466.229) but error threshold was exceeded
#
# 0034: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0035: [FAILED] subset cost = 22.520 (total cost = 583.419) but error threshold was exceeded
#
# 0036: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0037: [PASSED] subset cost = 7.158 (total cost = 420.561)
#
# 0038: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0039: [FAILED] subset cost = 6.606 (total cost = 406.871) but error threshold was exceeded
#
# 0040: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0041: [FAILED] subset cost = 6.948 (total cost = 411.429) but error threshold was exceeded
#
# 0042: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0043: [FAILED] subset cost = 17.217 (total cost = 485.896) but error threshold was exceeded
#
# 0044: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0045: [FAILED] subset cost = 7.136 (total cost = 411.660) but error threshold was exceeded
#
# 0046: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0047: [FAILED] subset cost = 15.081 (total cost = 480.544) but error threshold was exceeded
#
# 0048: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0049: [FAILED] subset cost = 12.440 (total cost = 463.397) but error threshold was exceeded
#
# 0050: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0051: [FAILED] subset cost = 17.218 (total cost = 514.996) but error threshold was exceeded
#
# 0052: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0053: [PASSED] subset cost = 20.978 (total cost = 573.081)
#
# 0054: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0055: [FAILED] subset cost = 8.114 (total cost = 417.885) but error threshold was exceeded
#
# 0056: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0057: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0058: [FAILED] subset cost = 23.039 (total cost = 605.460) but error threshold was exceeded
#
# 0059: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0060: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0061: [FAILED] subset cost = 6.527 (total cost = 407.517) but error threshold was exceeded
#
# 0062: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0063: [PASSED] subset cost = 6.907 (total cost = 410.770)
#
# 0064: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0065: [FAILED] subset cost = 6.562 (total cost = 411.874) but error threshold was exceeded
#
# 0066: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0067: [FAILED] subset cost = 6.450 (total cost = 406.085) but error threshold was exceeded
#
# 0068: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0069: [FAILED] subset cost = 6.244 (total cost = 426.916) but error threshold was exceeded
#
# 0070: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0071: [FAILED] subset cost = 10.447 (total cost = 441.819) but error threshold was exceeded
#
# 0072: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0073: [FAILED] subset cost = 18.842 (total cost = 528.212) but error threshold was exceeded
#
# 0074: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0075: [PASSED] subset cost = 10.282 (total cost = 454.409)
#
# 0076: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0077: [FAILED] subset cost = 7.087 (total cost = 418.763) but error threshold was exceeded
#
# 0078: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0079: [FAILED] subset cost = 6.723 (total cost = 405.129) but error threshold was exceeded
#
# 0080: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0081: [PASSED] subset cost = 6.737 (total cost = 407.916)
#
# 0082: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0083: [FAILED] subset cost = 6.583 (total cost = 403.153) but error threshold was exceeded
#
# 0084: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0085: [FAILED] subset cost = 6.220 (total cost = 406.659) but error threshold was exceeded
#
# 0086: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0087: [PASSED] subset cost = 6.219 (total cost = 406.507)
#
# 0088: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0089: [PASSED] subset cost = 14.172 (total cost = 468.095)
#
# 0090: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0091: [FAILED] subset cost = 7.911 (total cost = 414.072) but error threshold was exceeded
#
# 0092: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0093: [PASSED] subset cost = 6.761 (total cost = 406.945)
#
# 0094: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0095: [FAILED] subset cost = 6.642 (total cost = 408.462) but error threshold was exceeded
#
# 0096: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0097: [FAILED] subset cost = 12.725 (total cost = 452.217) but error threshold was exceeded
#
# 0098: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0099: [PASSED] subset cost = 8.084 (total cost = 422.183)
#
# 0100: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0101: [FAILED] subset cost = 6.986 (total cost = 408.533) but error threshold was exceeded
#
# 0102: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0103: [FAILED] subset cost = 13.106 (total cost = 464.788) but error threshold was exceeded
#
# 0104: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0105: [FAILED] subset cost = 16.354 (total cost = 505.878) but error threshold was exceeded
#
# 0106: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0107: [FAILED] subset cost = 7.571 (total cost = 423.563) but error threshold was exceeded
#
# 0108: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0109: [FAILED] subset cost = 12.683 (total cost = 456.539) but error threshold was exceeded
#
# 0110: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0111: [FAILED] subset cost = 12.021 (total cost = 466.956) but error threshold was exceeded
#
# 0112: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0113: [PASSED] subset cost = 6.690 (total cost = 404.605)
#
# 0114: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0115: [FAILED] subset cost = 8.245 (total cost = 414.784) but error threshold was exceeded
#
# 0116: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0117: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0118: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0119: [FAILED] subset cost = 6.363 (total cost = 410.041) but error threshold was exceeded
#
# 0120: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0121: [PASSED] subset cost = 12.406 (total cost = 453.746)
#
# 0122: [FAILED] subset cost = 13.324 (total cost = 529.456) but error threshold was exceeded
#
# 0123: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0124: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0125: [FAILED] subset cost = 6.790 (total cost = 406.521) but error threshold was exceeded
#
# 0126: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0127: [PASSED] subset cost = 6.676 (total cost = 407.173)
#
# 0128: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0129: [FAILED] subset cost = 6.732 (total cost = 411.440) but error threshold was exceeded
#
# 0130: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0131: [FAILED] subset cost = 6.853 (total cost = 413.770) but error threshold was exceeded
#
# 0132: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0133: [FAILED] subset cost = 6.259 (total cost = 431.380) but error threshold was exceeded
#
# 0134: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0135: [FAILED] subset cost = 10.532 (total cost = 442.859) but error threshold was exceeded
#
# 0136: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0137: [FAILED] subset cost = 18.890 (total cost = 530.640) but error threshold was exceeded
#
# 0138: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0139: [PASSED] subset cost = 10.241 (total cost = 460.946)
#
# 0140: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0141: [FAILED] subset cost = 7.416 (total cost = 424.933) but error threshold was exceeded
#
# 0142: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0143: [PASSED] subset cost = 7.004 (total cost = 410.316)
#
# 0144: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0145: [PASSED] subset cost = 7.190 (total cost = 412.479)
#
# 0146: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0147: [FAILED] subset cost = 6.783 (total cost = 406.722) but error threshold was exceeded
#
# 0148: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0149: [FAILED] subset cost = 6.867 (total cost = 410.979) but error threshold was exceeded
#
# 0150: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0151: [PASSED] subset cost = 14.287 (total cost = 466.257)
#
# 0152: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0153: [FAILED] subset cost = 7.595 (total cost = 415.589) but error threshold was exceeded
#
# 0154: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0155: [PASSED] subset cost = 6.668 (total cost = 407.240)
#
# 0156: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0157: [FAILED] subset cost = 7.136 (total cost = 416.168) but error threshold was exceeded
#
# 0158: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0159: [FAILED] subset cost = 12.885 (total cost = 459.551) but error threshold was exceeded
#
# 0160: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0161: [PASSED] subset cost = 8.002 (total cost = 420.947)
#
# 0162: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0163: [PASSED] subset cost = 6.480 (total cost = 413.022)
#
# 0164: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0165: [FAILED] subset cost = 12.857 (total cost = 464.681) but error threshold was exceeded
#
# 0166: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0167: [FAILED] subset cost = 13.909 (total cost = 507.425) but error threshold was exceeded
#
# 0168: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0169: [FAILED] subset cost = 7.245 (total cost = 423.152) but error threshold was exceeded
#
# 0170: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0171: [PASSED] subset cost = 13.231 (total cost = 465.505)
#
# 0172: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0173: [FAILED] subset cost = 11.608 (total cost = 478.540) but error threshold was exceeded
#
# 0174: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0175: [PASSED] subset cost = 6.406 (total cost = 409.790)
#
# 0176: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0177: [FAILED] subset cost = 8.093 (total cost = 421.171) but error threshold was exceeded
#
# 0178: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0179: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0180: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0181: [PASSED] subset cost = 6.468 (total cost = 414.801)
#
# 0182: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0183: [FAILED] subset cost = 11.638 (total cost = 452.395) but error threshold was exceeded
#
# 0184: [FAILED] subset cost = 13.976 (total cost = 533.358) but error threshold was exceeded
#
# 0185: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0186: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0187: [PASSED] subset cost = 6.647 (total cost = 403.703)
#
# 0188: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0189: [FAILED] subset cost = 6.920 (total cost = 406.682) but error threshold was exceeded
#
# 0190: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0191: [FAILED] subset cost = 6.728 (total cost = 406.644) but error threshold was exceeded
#
# 0192: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0193: [FAILED] subset cost = 6.826 (total cost = 407.717) but error threshold was exceeded
#
# 0194: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0195: [PASSED] subset cost = 6.932 (total cost = 407.408)
#
# 0196: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0197: [PASSED] subset cost = 6.620 (total cost = 406.301)
#
# 0198: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0199: [PASSED] subset cost = 6.827 (total cost = 404.672)
#
# 0200: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0201: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0202: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0203: [FAILED] subset cost = 6.830 (total cost = 422.127) but error threshold was exceeded
#
# 0204: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0205: [PASSED] subset cost = 6.770 (total cost = 405.554)
#
# 0206: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0207: [FAILED] subset cost = 9.749 (total cost = 438.281) but error threshold was exceeded
#
# 0208: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0209: [FAILED] subset cost = 16.689 (total cost = 527.172) but error threshold was exceeded
#
# 0210: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0211: [PASSED] subset cost = 6.149 (total cost = 404.478)
#
# 0212: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0213: [FAILED] subset cost = 7.712 (total cost = 425.407) but error threshold was exceeded
#
# 0214: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0215: [FAILED] subset cost = 9.441 (total cost = 455.427) but error threshold was exceeded
#
# 0216: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0217: [PASSED] subset cost = 6.795 (total cost = 403.686)
#
# 0218: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0219: [FAILED] subset cost = 7.169 (total cost = 408.070) but error threshold was exceeded
#
# 0220: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0221: [FAILED] subset cost = 7.279 (total cost = 413.685) but error threshold was exceeded
#
# 0222: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0223: [FAILED] subset cost = 6.526 (total cost = 405.351) but error threshold was exceeded
#
# 0224: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0225: [FAILED] subset cost = 6.492 (total cost = 408.553) but error threshold was exceeded
#
# 0226: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0227: [FAILED] subset cost = 6.734 (total cost = 408.860) but error threshold was exceeded
#
# 0228: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0229: [FAILED] subset cost = 6.942 (total cost = 406.923) but error threshold was exceeded
#
# 0230: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0231: [FAILED] subset cost = 7.189 (total cost = 406.808) but error threshold was exceeded
#
# 0232: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0233: [FAILED] subset cost = 6.767 (total cost = 406.925) but error threshold was exceeded
#
# 0234: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0235: [FAILED] subset cost = 6.463 (total cost = 408.626) but error threshold was exceeded
#
# 0236: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0237: [FAILED] subset cost = 14.786 (total cost = 468.109) but error threshold was exceeded
#
# 0238: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0239: [FAILED] subset cost = 7.938 (total cost = 413.405) but error threshold was exceeded
#
# 0240: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0241: [FAILED] subset cost = 6.896 (total cost = 406.040) but error threshold was exceeded
#
# 0242: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0243: [FAILED] subset cost = 6.451 (total cost = 406.048) but error threshold was exceeded
#
# 0244: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0245: [PASSED] subset cost = 7.039 (total cost = 409.423)
#
# 0246: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0247: [FAILED] subset cost = 6.675 (total cost = 409.424) but error threshold was exceeded
#
# 0248: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0249: [FAILED] subset cost = 6.154 (total cost = 406.083) but error threshold was exceeded
#
# 0250: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0251: [PASSED] subset cost = 13.039 (total cost = 462.030)
#
# 0252: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0253: [FAILED] subset cost = 8.211 (total cost = 421.144) but error threshold was exceeded
#
# 0254: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0255: [PASSED] subset cost = 6.378 (total cost = 412.786)
#
# 0256: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0257: [PASSED] subset cost = 6.835 (total cost = 408.415)
#
# 0258: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0259: [PASSED] subset cost = 7.067 (total cost = 417.565)
#
# 0260: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0261: [FAILED] subset cost = 6.963 (total cost = 411.454) but error threshold was exceeded
#
# 0262: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0263: [FAILED] subset cost = 16.008 (total cost = 484.171) but error threshold was exceeded
#
# 0264: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0265: [PASSED] subset cost = 10.950 (total cost = 460.552)
#
# 0266: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0267: [FAILED] subset cost = 6.922 (total cost = 413.005) but error threshold was exceeded
#
# 0268: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0269: [PASSED] subset cost = 7.448 (total cost = 418.085)
#
# 0270: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0271: [FAILED] subset cost = 6.952 (total cost = 411.475) but error threshold was exceeded
#
# 0272: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0273: [FAILED] subset cost = 12.985 (total cost = 463.007) but error threshold was exceeded
#
# 0274: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0275: [FAILED] subset cost = 14.695 (total cost = 493.132) but error threshold was exceeded
#
# 0276: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0277: [FAILED] subset cost = 8.690 (total cost = 460.406) but error threshold was exceeded
#
# 0278: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0279: [PASSED] subset cost = 6.455 (total cost = 405.356)
#
# 0280: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0281: [FAILED] subset cost = 6.860 (total cost = 408.252) but error threshold was exceeded
#
# 0282: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0283: [FAILED] subset cost = 6.724 (total cost = 410.513) but error threshold was exceeded
#
# 0284: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0285: [FAILED] subset cost = 13.118 (total cost = 458.234) but error threshold was exceeded
#
# 0286: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0287: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0288: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0289: [FAILED] subset cost = 7.154 (total cost = 413.922) but error threshold was exceeded
#
# 0290: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0291: [FAILED] subset cost = 6.754 (total cost = 407.894) but error threshold was exceeded
#
# 0292: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0293: [FAILED] subset cost = 6.775 (total cost = 409.707) but error threshold was exceeded
#
# 0294: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0295: [FAILED] subset cost = 12.441 (total cost = 454.065) but error threshold was exceeded
#
# 0296: [FAILED] subset cost = 13.839 (total cost = 526.062) but error threshold was exceeded
#
# 0297: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0298: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0299: [PASSED] subset cost = 7.071 (total cost = 411.526)
#
# 0300: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0301: [PASSED] subset cost = 6.811 (total cost = 405.888)
#
# 0302: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0303: [FAILED] subset cost = 6.856 (total cost = 407.971) but error threshold was exceeded
#
# 0304: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0305: [FAILED] subset cost = 6.818 (total cost = 406.033) but error threshold was exceeded
#
# 0306: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0307: [FAILED] subset cost = 6.887 (total cost = 407.225) but error threshold was exceeded
#
# 0308: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0309: [PASSED] subset cost = 6.935 (total cost = 406.066)
#
# 0310: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0311: [PASSED] subset cost = 6.431 (total cost = 405.251)
#
# 0312: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0313: [PASSED] subset cost = 6.327 (total cost = 406.459)
#
# 0314: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0315: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0316: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0317: [FAILED] subset cost = 6.758 (total cost = 421.842) but error threshold was exceeded
#
# 0318: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0319: [PASSED] subset cost = 6.753 (total cost = 403.773)
#
# 0320: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0321: [FAILED] subset cost = 10.382 (total cost = 443.143) but error threshold was exceeded
#
# 0322: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0323: [FAILED] subset cost = 19.223 (total cost = 531.116) but error threshold was exceeded
#
# 0324: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0325: [FAILED] subset cost = 7.767 (total cost = 423.718) but error threshold was exceeded
#
# 0326: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0327: [FAILED] subset cost = 9.047 (total cost = 456.774) but error threshold was exceeded
#
# 0328: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0329: [PASSED] subset cost = 6.782 (total cost = 406.295)
#
# 0330: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0331: [FAILED] subset cost = 7.027 (total cost = 408.142) but error threshold was exceeded
#
# 0332: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0333: [FAILED] subset cost = 7.543 (total cost = 412.923) but error threshold was exceeded
#
# 0334: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0335: [FAILED] subset cost = 6.822 (total cost = 408.083) but error threshold was exceeded
#
# 0336: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0337: [FAILED] subset cost = 7.192 (total cost = 408.713) but error threshold was exceeded
#
# 0338: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0339: [FAILED] subset cost = 6.497 (total cost = 407.912) but error threshold was exceeded
#
# 0340: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0341: [FAILED] subset cost = 5.978 (total cost = 406.813) but error threshold was exceeded
#
# 0342: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0343: [FAILED] subset cost = 7.100 (total cost = 406.041) but error threshold was exceeded
#
# 0344: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0345: [FAILED] subset cost = 6.870 (total cost = 404.601) but error threshold was exceeded
#
# 0346: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0347: [FAILED] subset cost = 6.454 (total cost = 405.572) but error threshold was exceeded
#
# 0348: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0349: [FAILED] subset cost = 14.800 (total cost = 468.095) but error threshold was exceeded
#
# 0350: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0351: [FAILED] subset cost = 7.889 (total cost = 417.738) but error threshold was exceeded
#
# 0352: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0353: [FAILED] subset cost = 6.737 (total cost = 407.344) but error threshold was exceeded
#
# 0354: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0355: [FAILED] subset cost = 6.999 (total cost = 405.688) but error threshold was exceeded
#
# 0356: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0357: [PASSED] subset cost = 6.791 (total cost = 410.660)
#
# 0358: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0359: [FAILED] subset cost = 6.855 (total cost = 410.890) but error threshold was exceeded
#
# 0360: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0361: [FAILED] subset cost = 6.441 (total cost = 405.394) but error threshold was exceeded
#
# 0362: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0363: [PASSED] subset cost = 12.821 (total cost = 455.237)
#
# 0364: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0365: [FAILED] subset cost = 8.049 (total cost = 423.505) but error threshold was exceeded
#
# 0366: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0367: [PASSED] subset cost = 6.874 (total cost = 409.696)
#
# 0368: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0369: [PASSED] subset cost = 6.316 (total cost = 404.308)
#
# 0370: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0371: [PASSED] subset cost = 7.214 (total cost = 416.340)
#
# 0372: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0373: [FAILED] subset cost = 6.302 (total cost = 411.803) but error threshold was exceeded
#
# 0374: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0375: [FAILED] subset cost = 15.925 (total cost = 480.321) but error threshold was exceeded
#
# 0376: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0377: [PASSED] subset cost = 10.667 (total cost = 462.176)
#
# 0378: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0379: [FAILED] subset cost = 6.925 (total cost = 412.580) but error threshold was exceeded
#
# 0380: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0381: [PASSED] subset cost = 7.371 (total cost = 417.025)
#
# 0382: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0383: [FAILED] subset cost = 6.968 (total cost = 410.080) but error threshold was exceeded
#
# 0384: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0385: [FAILED] subset cost = 13.691 (total cost = 466.304) but error threshold was exceeded
#
# 0386: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0387: [FAILED] subset cost = 14.528 (total cost = 494.228) but error threshold was exceeded
#
# 0388: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0389: [FAILED] subset cost = 9.150 (total cost = 460.938) but error threshold was exceeded
#
# 0390: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0391: [PASSED] subset cost = 6.786 (total cost = 404.330)
#
# 0392: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0393: [FAILED] subset cost = 6.986 (total cost = 409.164) but error threshold was exceeded
#
# 0394: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0395: [FAILED] subset cost = 6.942 (total cost = 409.380) but error threshold was exceeded
#
# 0396: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0397: [FAILED] subset cost = 12.278 (total cost = 458.650) but error threshold was exceeded
#
# 0398: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0399: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0400: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0401: [FAILED] subset cost = 6.626 (total cost = 411.995) but error threshold was exceeded
#
# 0402: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0403: [FAILED] subset cost = 6.966 (total cost = 409.493) but error threshold was exceeded
#
# 0404: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0405: [FAILED] subset cost = 6.737 (total cost = 410.547) but error threshold was exceeded
#
# 0406: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0407: [FAILED] subset cost = 11.258 (total cost = 447.280) but error threshold was exceeded
#
# 0408: [FAILED] subset cost = 13.922 (total cost = 525.793) but error threshold was exceeded
#
# 0409: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0410: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0411: [PASSED] subset cost = 6.863 (total cost = 411.038)
#
# 0412: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0413: [PASSED] subset cost = 6.522 (total cost = 407.202)
#
# 0414: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0415: [PASSED] subset cost = 6.707 (total cost = 404.949)
#
# 0416: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0417: [FAILED] subset cost = 6.803 (total cost = 406.178) but error threshold was exceeded
#
# 0418: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0419: [FAILED] subset cost = 6.999 (total cost = 406.333) but error threshold was exceeded
#
# 0420: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0421: [FAILED] subset cost = 6.868 (total cost = 406.750) but error threshold was exceeded
#
# 0422: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0423: [PASSED] subset cost = 6.731 (total cost = 405.603)
#
# 0424: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0425: [FAILED] subset cost = 6.944 (total cost = 408.481) but error threshold was exceeded
#
# 0426: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0427: [FAILED] subset cost = 6.869 (total cost = 408.274) but error threshold was exceeded
#
# 0428: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0429: [PASSED] subset cost = 6.407 (total cost = 405.718)
#
# 0430: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0431: [FAILED] subset cost = 6.646 (total cost = 405.956) but error threshold was exceeded
#
# 0432: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0433: [PASSED] subset cost = 6.783 (total cost = 405.370)
#
# 0434: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0435: [PASSED] subset cost = 6.828 (total cost = 403.238)
#
# 0436: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0437: [PASSED] subset cost = 6.815 (total cost = 404.880)
#
# 0438: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0439: [PASSED] subset cost = 6.277 (total cost = 407.766)
#
# 0440: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0441: [FAILED] subset cost = 6.903 (total cost = 411.712) but error threshold was exceeded
#
# 0442: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0443: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0444: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0445: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0446: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0447: [FAILED] subset cost = 6.940 (total cost = 413.277) but error threshold was exceeded
#
# 0448: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0449: [PASSED] subset cost = 6.367 (total cost = 405.645)
#
# 0450: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0451: [PASSED] subset cost = 6.833 (total cost = 407.869)
#
# 0452: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0453: [PASSED] subset cost = 7.157 (total cost = 406.108)
#
# 0454: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0455: [PASSED] subset cost = 10.046 (total cost = 435.585)
#
# 0456: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0457: [PASSED] subset cost = 13.251 (total cost = 465.246)
#
# 0458: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0459: [FAILED] subset cost = 8.734 (total cost = 439.024) but error threshold was exceeded
#
# 0460: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0461: [FAILED] subset cost = 6.902 (total cost = 421.150) but error threshold was exceeded
#
# 0462: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0463: [FAILED] subset cost = 7.030 (total cost = 423.528) but error threshold was exceeded
#
# 0464: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0465: [FAILED] subset cost = 8.814 (total cost = 447.042) but error threshold was exceeded
#
# 0466: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0467: [FAILED] subset cost = 9.093 (total cost = 447.802) but error threshold was exceeded
#
# 0468: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0469: [PASSED] subset cost = 6.891 (total cost = 408.816)
#
# 0470: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0471: [PASSED] subset cost = 6.903 (total cost = 407.345)
#
# 0472: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0473: [FAILED] subset cost = 6.917 (total cost = 405.004) but error threshold was exceeded
#
# 0474: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0475: [FAILED] subset cost = 6.581 (total cost = 407.417) but error threshold was exceeded
#
# 0476: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0477: [FAILED] subset cost = 7.310 (total cost = 412.481) but error threshold was exceeded
#
# 0478: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0479: [PASSED] subset cost = 6.813 (total cost = 406.713)
#
# 0480: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0481: [FAILED] subset cost = 6.270 (total cost = 408.705) but error threshold was exceeded
#
# 0482: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0483: [FAILED] subset cost = 6.499 (total cost = 407.923) but error threshold was exceeded
#
# 0484: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0485: [PASSED] subset cost = 6.827 (total cost = 409.606)
#
# 0486: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0487: [FAILED] subset cost = 6.677 (total cost = 407.648) but error threshold was exceeded
#
# 0488: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0489: [FAILED] subset cost = 6.105 (total cost = 409.725) but error threshold was exceeded
#
# 0490: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0491: [PASSED] subset cost = 6.784 (total cost = 405.072)
#
# 0492: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0493: [PASSED] subset cost = 6.574 (total cost = 408.778)
#
# 0494: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0495: [PASSED] subset cost = 6.718 (total cost = 408.570)
#
# 0496: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0497: [PASSED] subset cost = 6.298 (total cost = 411.137)
#
# 0498: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0499: [FAILED] subset cost = 6.725 (total cost = 412.607) but error threshold was exceeded
#
# 0500: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0501: [FAILED] subset cost = 6.726 (total cost = 406.031) but error threshold was exceeded
#
# 0502: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0503: [FAILED] subset cost = 6.551 (total cost = 410.138) but error threshold was exceeded
#
# 0504: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0505: [PASSED] subset cost = 6.469 (total cost = 408.928)
#
# 0506: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0507: [PASSED] subset cost = 6.529 (total cost = 408.399)
#
# 0508: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0509: [FAILED] subset cost = 11.904 (total cost = 448.491) but error threshold was exceeded
#
# 0510: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# ...
#
# 0687: [FAILED] subset cost = 7.669 (total cost = 423.729) but error threshold was exceeded
#
# 0688: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0689: [FAILED] subset cost = 9.216 (total cost = 450.158) but error threshold was exceeded
#
# 0690: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0691: [FAILED] subset cost = 9.347 (total cost = 454.651) but error threshold was exceeded
#
# 0692: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0693: [PASSED] subset cost = 6.249 (total cost = 408.404)
#
# 0694: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0695: [PASSED] subset cost = 6.687 (total cost = 408.572)
#
# 0696: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0697: [FAILED] subset cost = 6.748 (total cost = 409.238) but error threshold was exceeded
#
# 0698: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0699: [FAILED] subset cost = 6.806 (total cost = 409.556) but error threshold was exceeded
#
# 0700: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0701: [FAILED] subset cost = 7.065 (total cost = 415.224) but error threshold was exceeded
#
# 0702: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0703: [PASSED] subset cost = 6.052 (total cost = 410.868)
#
# 0704: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0705: [FAILED] subset cost = 6.739 (total cost = 410.425) but error threshold was exceeded
#
# 0706: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0707: [FAILED] subset cost = 6.755 (total cost = 412.946) but error threshold was exceeded
#
# 0708: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0709: [PASSED] subset cost = 6.468 (total cost = 410.880)
#
# 0710: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0711: [FAILED] subset cost = 6.377 (total cost = 409.913) but error threshold was exceeded
#
# 0712: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0713: [FAILED] subset cost = 6.648 (total cost = 409.969) but error threshold was exceeded
#
# 0714: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0715: [PASSED] subset cost = 6.225 (total cost = 406.652)
#
# 0716: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0717: [PASSED] subset cost = 6.605 (total cost = 408.292)
#
# 0718: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0719: [PASSED] subset cost = 7.039 (total cost = 410.832)
#
# 0720: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0721: [PASSED] subset cost = 6.807 (total cost = 406.481)
#
# 0722: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0723: [FAILED] subset cost = 6.824 (total cost = 409.325) but error threshold was exceeded
#
# 0724: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0725: [FAILED] subset cost = 6.792 (total cost = 406.768) but error threshold was exceeded
#
# 0726: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0727: [FAILED] subset cost = 6.632 (total cost = 409.653) but error threshold was exceeded
#
# 0728: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0729: [PASSED] subset cost = 6.702 (total cost = 408.215)
#
# 0730: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0731: [PASSED] subset cost = 6.663 (total cost = 409.602)
#
# 0732: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0733: [FAILED] subset cost = 11.609 (total cost = 446.705) but error threshold was exceeded
#
# 0734: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0735: [FAILED] subset cost = 8.742 (total cost = 426.633) but error threshold was exceeded
#
# 0736: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0737: [FAILED] subset cost = 7.460 (total cost = 414.840) but error threshold was exceeded
#
# 0738: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0739: [FAILED] subset cost = 6.387 (total cost = 408.136) but error threshold was exceeded
#
# 0740: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0741: [FAILED] subset cost = 6.695 (total cost = 411.244) but error threshold was exceeded
#
# 0742: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0743: [FAILED] subset cost = 6.579 (total cost = 408.786) but error threshold was exceeded
#
# 0744: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0745: [FAILED] subset cost = 6.528 (total cost = 407.592) but error threshold was exceeded
#
# 0746: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0747: [FAILED] subset cost = 6.207 (total cost = 407.588) but error threshold was exceeded
#
# 0748: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0749: [PASSED] subset cost = 6.183 (total cost = 407.885)
#
# 0750: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0751: [FAILED] subset cost = 6.582 (total cost = 413.420) but error threshold was exceeded
#
# 0752: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0753: [FAILED] subset cost = 6.262 (total cost = 409.787) but error threshold was exceeded
#
# 0754: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0755: [FAILED] subset cost = 6.542 (total cost = 411.259) but error threshold was exceeded
#
# 0756: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0757: [PASSED] subset cost = 6.596 (total cost = 405.377)
#
# 0758: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0759: [PASSED] subset cost = 6.101 (total cost = 407.173)
#
# 0760: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0761: [PASSED] subset cost = 10.477 (total cost = 440.180)
#
# 0762: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0763: [FAILED] subset cost = 7.406 (total cost = 420.348) but error threshold was exceeded
#
# 0764: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0765: [PASSED] subset cost = 7.829 (total cost = 424.254)
#
# 0766: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0767: [PASSED] subset cost = 6.912 (total cost = 414.799)
#
# 0768: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0769: [FAILED] subset cost = 6.401 (total cost = 409.613) but error threshold was exceeded
#
# 0770: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0771: [FAILED] subset cost = 6.895 (total cost = 412.494) but error threshold was exceeded
#
# 0772: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0773: [PASSED] subset cost = 6.296 (total cost = 409.190)
#
# 0774: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0775: [PASSED] subset cost = 6.243 (total cost = 406.829)
#
# 0776: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0777: [FAILED] subset cost = 6.668 (total cost = 410.608) but error threshold was exceeded
#
# 0778: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0779: [FAILED] subset cost = 7.204 (total cost = 416.999) but error threshold was exceeded
#
# 0780: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0781: [FAILED] subset cost = 7.027 (total cost = 415.127) but error threshold was exceeded
#
# 0782: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0783: [PASSED] subset cost = 12.064 (total cost = 457.523)
#
# 0784: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0785: [FAILED] subset cost = 8.852 (total cost = 430.546) but error threshold was exceeded
#
# 0786: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0787: [PASSED] subset cost = 10.688 (total cost = 473.471)
#
# 0788: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0789: [FAILED] subset cost = 8.345 (total cost = 444.535) but error threshold was exceeded
#
# 0790: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0791: [FAILED] subset cost = 7.128 (total cost = 414.793) but error threshold was exceeded
#
# 0792: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0793: [PASSED] subset cost = 6.480 (total cost = 404.676)
#
# 0794: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0795: [PASSED] subset cost = 6.810 (total cost = 408.430)
#
# 0796: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0797: [PASSED] subset cost = 6.675 (total cost = 419.275)
#
# 0798: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0799: [PASSED] subset cost = 6.583 (total cost = 411.413)
#
# 0800: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0801: [FAILED] subset cost = 6.892 (total cost = 416.431) but error threshold was exceeded
#
# 0802: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0803: [FAILED] subset cost = 7.734 (total cost = 424.895) but error threshold was exceeded
#
# 0804: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0805: [FAILED] subset cost = 10.609 (total cost = 441.593) but error threshold was exceeded
#
# 0806: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0807: [PASSED] subset cost = 9.552 (total cost = 458.214)
#
# 0808: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0809: [FAILED] subset cost = 12.744 (total cost = 477.399) but error threshold was exceeded
#
# 0810: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0811: [FAILED] subset cost = 8.318 (total cost = 434.491) but error threshold was exceeded
#
# 0812: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0813: [FAILED] subset cost = 6.628 (total cost = 415.808) but error threshold was exceeded
#
# 0814: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0815: [PASSED] subset cost = 6.453 (total cost = 408.619)
#
# 0816: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0817: [PASSED] subset cost = 6.775 (total cost = 408.110)
#
# 0818: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0819: [PASSED] subset cost = 6.947 (total cost = 409.922)
#
# 0820: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0821: [FAILED] subset cost = 6.878 (total cost = 409.582) but error threshold was exceeded
#
# 0822: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0823: [FAILED] subset cost = 6.781 (total cost = 409.428) but error threshold was exceeded
#
# 0824: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0825: [FAILED] subset cost = 6.822 (total cost = 409.356) but error threshold was exceeded
#
# 0826: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0827: [FAILED] subset cost = 7.969 (total cost = 421.226) but error threshold was exceeded
#
# 0828: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0829: [PASSED] subset cost = 10.690 (total cost = 435.016)
#
# 0830: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0831: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0832: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0833: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0834: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0835: [FAILED] subset cost = 6.923 (total cost = 414.470) but error threshold was exceeded
#
# 0836: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0837: [PASSED] subset cost = 6.804 (total cost = 407.703)
#
# 0838: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0839: [PASSED] subset cost = 6.241 (total cost = 405.978)
#
# 0840: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0841: [FAILED] subset cost = 6.969 (total cost = 413.189) but error threshold was exceeded
#
# 0842: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0843: [PASSED] subset cost = 6.668 (total cost = 406.547)
#
# 0844: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0845: [FAILED] subset cost = 6.689 (total cost = 411.863) but error threshold was exceeded
#
# 0846: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0847: [PASSED] subset cost = 6.403 (total cost = 405.952)
#
# 0848: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0849: [FAILED] subset cost = 11.760 (total cost = 452.675) but error threshold was exceeded
#
# 0850: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0851: [FAILED] subset cost = 7.769 (total cost = 421.670) but error threshold was exceeded
#
# 0852: [FAILED] subset cost = 11.482 (total cost = 513.160) but error threshold was exceeded
#
# 0853: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0854: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0855: [FAILED] subset cost = 6.942 (total cost = 409.585) but error threshold was exceeded
#
# 0856: [FAILED] (runtime failure) unable to execute transformed source code (see outlog.txt for details)
#
# 0857: [FAILED] subset cost = 6.830 (total cost = 411.658) but error threshold was exceeded
#
#
#
#           Original cost = 6.310
#
# Best FAILED: 0645, cost = 5.808 (1.086x speedup)
#
# Best PASSED: 0703, cost = 6.052 (1.043x speedup)

# %%
fig, df_plot = plot_performance_vs_correctness(df_entire, error_type=ERROR_METRICS[1], norm="L2 norm")
fig.show()
# Out:
# <div>                            <div id="a465b30a-a0cf-49a8-a3f1-de0413a45b82" class="plotly-graph-div" style="height:300px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a465b30a-a0cf-49a8-a3f1-de0413a45b82")) {                    Plotly.newPlot(                        "a465b30a-a0cf-49a8-a3f1-de0413a45b82",                        [{"customdata":[[0],[3],[5],[7],[9],[10],[13],[15],[17],[19],[21],[23],[25],[26],[29],[31],[33],[35],[37],[39],[41],[43],[45],[47],[49],[51],[53],[55],[58],[61],[63],[65],[67],[69],[71],[73],[75],[77],[79],[81],[83],[85],[87],[89],[91],[93],[95],[97],[99],[101],[103],[105],[107],[109],[111],[113],[115],[119],[121],[122],[125],[127],[129],[131],[133],[135],[137],[139],[141],[143],[145],[147],[149],[151],[153],[155],[157],[159],[161],[163],[165],[167],[169],[171],[173],[175],[177],[181],[183],[184],[187],[189],[191],[193],[195],[197],[199],[203],[205],[207],[209],[211],[213],[215],[217],[219],[221],[223],[225],[227],[229],[231],[233],[235],[237],[239],[241],[243],[245],[247],[249],[251],[253],[255],[257],[259],[261],[263],[265],[267],[269],[271],[273],[275],[277],[279],[281],[283],[285],[289],[291],[293],[295],[296],[299],[301],[303],[305],[307],[309],[311],[313],[317],[319],[321],[323],[325],[327],[329],[331],[333],[335],[337],[339],[341],[343],[345],[347],[349],[351],[353],[355],[357],[359],[361],[363],[365],[367],[369],[371],[373],[375],[377],[379],[381],[383],[385],[387],[389],[391],[393],[395],[397],[401],[403],[405],[407],[408],[411],[413],[415],[417],[419],[421],[423],[425],[427],[429],[431],[433],[435],[437],[439],[441],[447],[449],[451],[453],[455],[457],[459],[461],[463],[465],[467],[469],[471],[473],[475],[477],[479],[481],[483],[485],[487],[489],[491],[493],[495],[497],[499],[501],[503],[505],[507],[509],[511],[513],[515],[517],[519],[521],[523],[525],[527],[529],[531],[533],[535],[537],[539],[541],[543],[545],[547],[549],[551],[553],[555],[557],[559],[561],[563],[565],[567],[569],[571],[573],[575],[577],[579],[581],[583],[585],[587],[589],[591],[593],[595],[597],[599],[601],[603],[605],[607],[613],[615],[617],[619],[621],[623],[625],[627],[629],[630],[633],[635],[637],[639],[641],[643],[645],[647],[649],[651],[653],[655],[657],[659],[661],[663],[665],[671],[673],[675],[677],[679],[681],[683],[685],[687],[689],[691],[693],[695],[697],[699],[701],[703],[705],[707],[709],[711],[713],[715],[717],[719],[721],[723],[725],[727],[729],[731],[733],[735],[737],[739],[741],[743],[745],[747],[749],[751],[753],[755],[757],[759],[761],[763],[765],[767],[769],[771],[773],[775],[777],[779],[781],[783],[785],[787],[789],[791],[793],[795],[797],[799],[801],[803],[805],[807],[809],[811],[813],[815],[817],[819],[821],[823],[825],[827],[829],[835],[837],[839],[841],[843],[845],[847],[849],[851],[852],[855],[857]],"hovertemplate":"Improvement=%{x}<br>Maximum CFL (L2 norm)=%{y}<br>Configuration Number=%{customdata[0]}<br>32-bit %=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0.0,50.142450142450144,25.071225071225072,25.071225071225072,25.071225071225072,75.21367521367522,12.535612535612536,12.535612535612536,12.535612535612536,12.535612535612536,12.535612535612536,12.535612535612536,12.535612535612536,87.74928774928775,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,6.267806267806268,94.01709401709401,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.133903133903134,3.1339031339 ...

# %%
df_subset[(df_subset["Procedure Name"] == procedure_name) & (df_subset["Configuration Number"] == 0)]["config_hash"].values[0]
# Out:
# -7709736075822909268

# %%
from plotly.subplots import make_subplots

df_subset["Average CPU Time Per Call"] = df_subset["CPU Time"] / df_subset["Execution Count"]
for procedure_name in df_subset[df_subset["Procedure Name"].str.contains("::")]["Procedure Name"].unique():
    if "flux_adjust" in procedure_name:
        continue # don't take the average of all 64-bit variants of flux-adjust routines which are noisy
    for config_hash in df_subset[df_subset["Procedure Name"] == procedure_name]["config_hash"].unique():
        df_subset.loc[(df_subset["Procedure Name"] == procedure_name) & (df_subset["config_hash"] == config_hash), "Average CPU Time Per Call"] = df_subset.loc[(df_subset["Procedure Name"] == procedure_name) & (df_subset["config_hash"] == config_hash), "Average CPU Time Per Call"].mean()

baseline_costs = {
    '::mom_continuity_ppm::zonal_flux_layer' : 1.4869062499999997,
    # '::mom_continuity_ppm::merid_flux_layer' : 1.3342421875000001,
    '::mom_continuity_ppm::zonal_mass_flux' : 0.5896171875,
    # '::mom_continuity_ppm::meridional_mass_flux' : 0.46635546875,
    '::mom_continuity_ppm::zonal_flux_adjust' : 0.5046796875,
    # '::mom_continuity_ppm::meridional_flux_adjust' : 0.39278515625,
    '::mom_continuity_ppm::set_zonal_bt_cont' : 0.41324609375,
    # '::mom_continuity_ppm::set_merid_bt_cont' : 0.35382031249999996,
    # '::mom_continuity_ppm::ppm_reconstruction_x' : 0.27198828125,
    # '::mom_continuity_ppm::ppm_reconstruction_y' : 0.22505468750000002,
    # '::mom_continuity_ppm::ppm_limit_pos' : 0.160015625,
    # '::mom_continuity_ppm::merid_face_thickness' : 0.15793749999999995,
    '::mom_continuity_ppm::zonal_face_thickness' : 0.15079687499999997,
    # '::mom_continuity_ppm::continuity_ppm' : 0.12741796875,
    # '::mom_continuity_ppm::continuity_ppm_init' : 1.10312109375e-05,
}

procedure_percentages = {
    '::mom_continuity_ppm::zonal_flux_layer': "22.4",#22.43212079470703,
    '::mom_continuity_ppm::merid_flux_layer': "20.1", #20.113111263774215,
    '::mom_continuity_ppm::zonal_mass_flux': "9.0",#8.9596406665791,
    '::mom_continuity_ppm::meridional_mass_flux': "7.0",#7.023666416682972,
    '::mom_continuity_ppm::zonal_flux_adjust': "7.6",#7.572937598608928,
    '::mom_continuity_ppm::meridional_flux_adjust': "5.9",#5.874188908917873,
    '::mom_continuity_ppm::set_zonal_bt_cont': "6.3",#6.251864356826961,
    '::mom_continuity_ppm::set_merid_bt_cont': "5.3",#5.334637994911223,
    '::mom_continuity_ppm::ppm_reconstruction_x': "4.1",#4.102172995990434,
    '::mom_continuity_ppm::ppm_reconstruction_y': "3.4",#3.398163531154783,
    '::mom_continuity_ppm::ppm_limit_pos': "2.4",#2.4479508889011354,
    '::mom_continuity_ppm::merid_face_thickness': "2.4",#2.401824905137172,
    '::mom_continuity_ppm::zonal_face_thickness': "2.3",#2.3120783396943727,
    '::mom_continuity_ppm::continuity_ppm': "2.0",#1.9538947557998065,
    '::mom_continuity_ppm::continuity_ppm_init': "<0.001",#0.00017002637389540776
}

fig = make_subplots(len(baseline_costs),1, subplot_titles=tuple([f'{x[x.rfind(":") + 1:]} ({procedure_percentages[x]}%)' for x in baseline_costs.keys()]), shared_xaxes=True, vertical_spacing=0.09)
for i, procedure_name in enumerate(baseline_costs.keys()):
    df_plot = df_subset[df_subset["Procedure Name"] == procedure_name]
    # baseline_cost = baseline_costs[procedure_name] / df_plot[df_plot["Configuration Number"] == 0]["Execution Count"].values[0]
    # baseline_cost = (baseline_cost + df_plot[df_plot["Configuration Number"] == 0]["Average CPU Time Per Call"].values[0]) / 2
    baseline_cost = df_plot[df_plot["Configuration Number"] == 0]["Average CPU Time Per Call"].values[0]
    df_plot = df_plot.assign(Improvement = np.round(baseline_cost/df_plot['Average CPU Time Per Call'], decimals=2))
    if "flux_adjust" in procedure_name: # reduce crowding of flux adjust variants with > 0.1x improvement
        df_plot.loc[df_plot["Improvement"] > 0.1, "Improvement"] = np.round(df_plot[df_plot["Improvement"] > 0.1]["Improvement"], decimals=1)
    df_plot = df_plot.drop_duplicates(subset=["config_hash","Improvement"])
    fig.add_trace(
        go.Scatter(
            x = df_plot["Improvement"],
            y = np.random.rand(len(df_subset)),
            mode = 'markers',
            customdata=df_plot["Configuration Number"],
            hovertemplate="%{customdata}",
            marker = dict(
                size = 10,
                color=df_plot["32-bit %"],
                line_width = 1,
                line_color = "black",
                opacity = 0.6,
                coloraxis="coloraxis1",
                symbol = "diamond",
            ),
            showlegend=False
        ),
        i + 1,
        1
    )
    if i == 0:
        fig.update_traces(
            marker_colorbar_title = "% 32-bit",
            marker_colorscale = "Plasma",
        )


    # df_plot = df_plot[df_plot["Configuration Number"] == df_entire[df_entire["Cost"] == df_entire[df_entire["Label"] == "Passed"]["Cost"].min()]["Configuration Number"].values[0]]
    # fig.add_trace(
    #     go.Scatter(
    #         x = df_plot["Improvement"],
    #         y = [0],
    #         mode = 'markers',
    #         customdata=[df_plot["Configuration Number"]],
    #         hovertemplate="%{customdata}",
    #         marker = dict(
    #             size = 15,
    #             color=df_plot["32-bit %"],
    #             line_width= 1,
    #             line_color="black",
    #             coloraxis="coloraxis1",
    #             symbol="star",
    #         ),
    #         name = "Optimal Variant",
    #         showlegend=[True if i == 0 else False for x in range(1)][0],
    #     ),
    #     row = i + 1,
    #     col = 1,
    # )

fig.update_layout(
    width = 600,
    height = 400,
    showlegend = False,
    margin = dict(
        r = 0,
        t = 60,
        b = 100,
        l = 0,
    ),
    title=dict(
        text = "MOM6",
        y = 0.98,
        x = 0.5,
        xanchor = 'center',
        yanchor = 'top',
        font_size=30,
    ),
    font_size = 24,
    font_family = "Times New Roman",
    coloraxis={
        "cmin" : 0,
        "cmax" : 100,
        "colorbar" : {
            'thickness' : 18,
            'title' : "% 32-bit<br>(Procedure)",
            'orientation' : 'h',
            'title_font_size' : 24,
            'y' : -0.6,
            'len' : 0.8
        },
    },
    legend = dict(
        bgcolor = "#E5ECF6",
        entrywidth = 130,
        orientation = "h",
        yanchor = "bottom",
        xanchor = "right",
        x = 1.0,
        y = 1.02,
        title_text = ""
    ),
)

fig.update_xaxes(type="log", ticksuffix="x")
# fig.update_xaxes(title="Speedup", row=len(baseline_costs), col=1)
fig.update_yaxes(visible=False)
fig.update_annotations(yshift=-5, font_size=18)
# fig.add_vline(x=1.0, line_width=2, line_dash="dash", line_color="grey")
fig.show()
# Out:
# <div>                            <div id="903c7302-ed9a-43f2-91de-697e1f297804" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("903c7302-ed9a-43f2-91de-697e1f297804")) {                    Plotly.newPlot(                        "903c7302-ed9a-43f2-91de-697e1f297804",                        [{"customdata":[0,3,5,7,73,75,211,213,215,325,327,461,463,465,467],"hovertemplate":"%{customdata}","marker":{"color":[0.0,100.0,94.11764705882352,5.88235294117647,29.411764705882355,64.70588235294117,35.294117647058826,35.294117647058826,29.411764705882355,70.58823529411765,64.70588235294117,52.94117647058824,52.94117647058824,52.94117647058824,47.05882352941176],"coloraxis":"coloraxis","line":{"color":"black","width":1},"opacity":0.6,"size":10,"symbol":"diamond","colorbar":{"title":{"text":"% 32-bit"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"mode":"markers","showlegend":false,"x":[1.0,0.77,1.11,1.07,1.07,0.8,1.0,1.01,1.21,0.9,1.05,1.13,1.06,1.18,1.08],"y":[0.5432569026443071,0.6207642874309125,0.3988516217145217,0.6203482074633188,0.3308268697139167,0.19770508807284803,0.5045358646604496,0.3366556258722929,0.23436654698250814,0.4019496049032163,0.44199980698632624,0.6259700385036725,0.6547498992564854,0.1290194396402382,0.459838564244774,0.8810619378333878,0.0713634641014983,0.836426056473864,0.011705668236943856,0.9753517237239947,0.9992052944144711,0.6898102665895463,0.2256904029449368,0.6258469523351868,0.8359512123327887,0.6983254059227542,0.2694130733438188,0.6277031878231425,0.26130090046988275,0.8515466624994283,0.8406608415388058,0.3718084537704832,0.06627363049989488,0.23455569136693422,0.08521362008340261,0.5665389376469725,0.4986705970557974,0.6098760749658376,0.2907172890666967,0.18598072522213538,0.3426794515095196,0.908952914327834,0.15229441202393357,0.33653155156582426,0.3740667070636301,0.9178685833749203,0.2704028321819937,0.7214277756420978,0.14365242182270743,0.5309489687062279,0.3182003536824739,0.163239611203978,0.08951737383231217,0.059501579199699894,0.8253642193665175,0.06307382186389443,0.3262106140474389,0.8223838645680838,0.1866079360794639,0.7562994876268561,0.8606373192413567,0.4421374464631507,0.9982731530295496,0.43977779057865396,0.5178629775120517,0.7969201984838289,0.17374867682001505,0.39403045012963467,0.4648585734242934,0.7904918609945725,0.36588925772803504,0.6815993723988344,0.8946085667895508,0.7543723663742116,0.5133746310450494,0.795911412532934,0.6604927747376371,0.6407244535673948,0.44298473805358574,0.7351828649493174,0.015213553852605144,0.13962157017207122,0.8022675829781313,0.5767735250111908,0.6090397917477147,0.24942437857401467,0.8924499495581064,0.2873286775543409,0.9723043650396956,0.09336190732819505,0.773622971223824,0.09183855626967619,0.6295204861717622,0.6788525205925897,0.7677232416865355,0.49938191305658086,0.8727751129473171,0.7871098209802475,0.07649255261915644,0.9918617507959039,0.9436567552560181,0.5870731504523209,0.603852035056995,0.48449037928654215,0.8564060942818239,0.6701915403921549,0.7415899461536966,0.01429012200302382,0.6276412863210317,0.38772297874674944,0.9517341026542628,0.2229188304439378,0.6865287049174374,0.39904550660747506,0.03238411650991657,0.03602289386483204,0.7292018199391208,0.33305803122527244,0.13292660945972268,0.7582190349826737,0.7008598005280652,0.03583355942232913,0.9454943775277908,0.7350848701773894,0.4904686030232329,0.779241241306343,0.4484751180716038,0.06332742079360643,0.5054444170605632,0.9097817996766602,0.7056440861077482,0.50402331695597,0.078089 ...

# %%
df_plot = df_subset[df_subset["Procedure Name"] == "::mom_continuity_ppm::zonal_flux_adjust"]
# baseline_cost = baseline_costs[procedure_name] / df_plot[df_plot["Configuration Number"] == 0]["Execution Count"].values[0]
# baseline_cost = (baseline_cost + df_plot[df_plot["Configuration Number"] == 0]["Average CPU Time Per Call"].values[0]) / 2
baseline_cost = df_plot[df_plot["Configuration Number"] == 0]["Average CPU Time Per Call"].values[0]
df_plot = df_plot.assign(Improvement = np.round(baseline_cost/df_plot['Average CPU Time Per Call'], decimals=2))

# %%
df_plot.loc[df_plot["Improvement"] > 0.1, "Improvement"] = np.round(df_plot[df_plot["Improvement"] > 0.1]["Improvement"], decimals=1)
df_plot[df_plot["Improvement"] > 0.1]["Improvement"]
# Out:
# 10      1.0
# 31      1.1
# 58      0.7
# 78      0.9
# 100     0.9
#        ...
# 7881    0.9
# 7903    0.6
# 7926    0.7
# 7974    0.8
# 7994    0.8
# Name: Improvement, Length: 381, dtype: float64

# %%
# Out:
# 10      1.0
# 31      1.1
# 58      0.7
# 78      0.9
# 100     0.9
#        ...
# 7881    0.9
# 7903    0.6
# 7926    0.7
# 7974    0.8
# 7994    0.8
# Name: Improvement, Length: 381, dtype: float64

# %%
df_subset[(df_subset["Configuration Number"] == 25) & (df_subset["Procedure Name"] == "::mom_continuity_ppm::zonal_flux_adjust")]
# Out:
#      Configuration Number               Configuration Path   32-bit %  \
# 274                    25  ./prose_logs/0025/config_FAILED  67.741935
#
#                         Label  Energy/Mass (L2 norm)  Maximum CFL (L2 norm)  \
# 274  Exceeded Error Threshold               0.011517               0.275678
#
#      Mean Sea Level (L2 norm)  Total Mass (L2 norm)  Mean Salin (L2 norm)  \
# 274                       0.0                   0.0                   0.0
#
#      Frac Mass Err (L2 norm)  ...  Mean Salin (inf norm)  \
# 274                61.223669  ...                    0.0
#
#      Frac Mass Err (inf norm)  Salin Err (inf norm)  Temp Err (inf norm)  \
# 274                  51.27027            160.643836             0.169877
#
#        Cost                           Procedure Name  CPU Time  \
# 274  23.929  ::mom_continuity_ppm::zonal_flux_adjust  1.588852
#
#      Execution Count         config_hash  Average CPU Time Per Call
# 274       32000000.0 -633756409881252446               4.675324e-08
#
# [1 rows x 26 columns]

# %%
df_subset[(df_subset["Configuration Number"] == 575) & (df_subset["Procedure Name"] == "::mom_continuity_ppm::zonal_flux_adjust")]
# Out:
#       Configuration Number               Configuration Path  32-bit %   Label  \
# 5386                   575  ./prose_logs/0575/config_PASSED  9.677419  Passed
#
#       Energy/Mass (L2 norm)  Maximum CFL (L2 norm)  Mean Sea Level (L2 norm)  \
# 5386                0.01501               0.195036                       0.0
#
#       Total Mass (L2 norm)  Mean Salin (L2 norm)  Frac Mass Err (L2 norm)  \
# 5386                   0.0                   0.0               109.112806
#
#       ...  Mean Salin (inf norm)  Frac Mass Err (inf norm)  \
# 5386  ...                    0.0                 100.72973
#
#       Salin Err (inf norm)  Temp Err (inf norm)   Cost  \
# 5386             176.39726             0.423729  7.009
#
#                                Procedure Name  CPU Time  Execution Count  \
# 5386  ::mom_continuity_ppm::zonal_flux_adjust  0.556938        7100000.0
#
#               config_hash  Average CPU Time Per Call
# 5386  4833932883432278975               6.878336e-08
#
# [1 rows x 26 columns]

# %%
df_subset[(df_subset["Configuration Number"] == 0) & (df_subset["Procedure Name"] == "::mom_continuity_ppm::zonal_flux_adjust")]
# Out:
#     Configuration Number               Configuration Path  32-bit %   Label  \
# 10                     0  ./prose_logs/0000/config_PASSED       0.0  Passed
#
#     Energy/Mass (L2 norm)  Maximum CFL (L2 norm)  Mean Sea Level (L2 norm)  \
# 10                    0.0                    0.0                       0.0
#
#     Total Mass (L2 norm)  Mean Salin (L2 norm)  Frac Mass Err (L2 norm)  ...  \
# 10                   0.0                   0.0                      0.0  ...
#
#     Mean Salin (inf norm)  Frac Mass Err (inf norm)  Salin Err (inf norm)  \
# 10                    0.0                       0.0                   0.0
#
#     Temp Err (inf norm)  Cost                           Procedure Name  \
# 10                  0.0  6.31  ::mom_continuity_ppm::zonal_flux_adjust
#
#     CPU Time  Execution Count          config_hash  Average CPU Time Per Call
# 10  0.470016        7500000.0  3695226326670877943               2.840622e-07
#
# [1 rows x 26 columns]
